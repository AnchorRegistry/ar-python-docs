# %% [markdown]
# # DataFrame Analytics
#
# Load the full registry into a pandas DataFrame and run analytics.
#
# Requires the analytics extra:
#
# ```bash
# pip install anchorregistry[analytics]
# ```
#
# > These examples run against Sepolia testnet (`network="sepolia"`).
# > To run against Base mainnet: replace `configure(network="sepolia")` with `configure(network="base")`.
# > All function calls, record structures, and output shapes are identical across networks.

# %%
# Cell 1 — setup
from anchorregistry import configure, get_all, to_dataframe
import pandas as pd

configure(network="sepolia", rpc_url="https://ethereum-sepolia-rpc.publicnode.com")

# %%
# Cell 2 — load full registry into DataFrame
df = to_dataframe(get_all())
print(f"Shape: {df.shape}")
df.dtypes
# Out:
# Shape: (13, 28)
# ar_id                       str
# registered                 bool
# artifact_type_index       int64
# artifact_type_name          str
# tx                          str
# block                     int64
# registrant                  str
# manifest_hash               str
# parent_ar_id                str
# descriptor                  str
# title                       str
# author                      str
# tree_id                     str
# token_commitment            str
# research_doi                str
# research_institution        str
# research_co_authors         str
# research_url                str
# data_data_version           str
# data_format                 str
# data_row_count              str
# data_schema_url             str
# data_url                    str
# model_model_version         str
# model_architecture          str
# model_parameters            str
# model_training_dataset      str
# model_url                   str
# dtype: object

# %%
# Cell 3 — filter by artifact type
# Type-specific data fields are flattened as {type_name}_{field_name}
# e.g. RESEARCH fields -> research_doi, research_institution, research_co_authors, research_url
research_df = df[df.artifact_type_name == "RESEARCH"]
cols = ["ar_id", "title", "research_doi", "research_institution", "research_url"]
research_df[[c for c in cols if c in research_df.columns]]
# Out:
#               ar_id          title research_doi research_institution  \
# 0   AR-2026-86pNJz1  test research
# 1   AR-2026-yPZBeoP  test research
# 2   AR-2026-A5kgmm5  test research
# 3   AR-2026-L5RMpQ6  test research
# 5   AR-2026-76ELKeP  test research
# 6   AR-2026-e5enrj1  test research
# 7   AR-2026-z19q0J1  test research
# 8   AR-2026-BPaGWr5  test research
# 9   AR-2026-b5VeMB6  test research
# 10  AR-2026-j1BgLvP  test research
#
#           research_url
# 0   https://arxiv.org/
# 1   https://arxiv.org/
# 2   https://arxiv.org/
# 3   https://arxiv.org/
# 5   https://arxiv.org/
# 6   https://arxiv.org/
# 7   https://arxiv.org/
# 8   https://arxiv.org/
# 9   https://arxiv.org/
# 10  https://arxiv.org/

# %%
# Cell 4 — filter by registrant
registrant_df = df[df.registrant == "0xc7a7afde1177fbf0bb265ea5a616d1b8d7ed8c44"]
registrant_df[["ar_id", "artifact_type_name", "title"]]
# Out:
#               ar_id artifact_type_name          title
# 0   AR-2026-86pNJz1           RESEARCH  test research
# 1   AR-2026-yPZBeoP           RESEARCH  test research
# 2   AR-2026-A5kgmm5           RESEARCH  test research
# 3   AR-2026-L5RMpQ6           RESEARCH  test research
# 4   AR-2026-o5D0Ky5               DATA      test data
# 5   AR-2026-76ELKeP           RESEARCH  test research
# 6   AR-2026-e5enrj1           RESEARCH  test research
# 7   AR-2026-z19q0J1           RESEARCH  test research
# 8   AR-2026-BPaGWr5           RESEARCH  test research
# 9   AR-2026-b5VeMB6           RESEARCH  test research
# 10  AR-2026-j1BgLvP           RESEARCH  test research
# 11  AR-2026-APzR4bP               DATA      test date
# 12  AR-2026-Q5Kv7B6              MODEL     test model

# %%
# Cell 5 — group by artifact type
df.groupby("artifact_type_name").size().sort_values(ascending=False)
# Out:
# artifact_type_name
# RESEARCH    10
# DATA         2
# MODEL        1
# dtype: int64

# %%
# Cell 6 — tree analysis
df.groupby("tree_id").size().sort_values(ascending=False)
# Out:
# tree_id
# 0x21e24ef8dcf0954d82496cf6126f97bfe68e4a906d52790dc7d037b3b4295920    2
# 0x56d1414373fca0dc195cd48040fbd57f177eddb10ca1266b02e9bc462b6aa672    2
# 0xc17ebcafce735716b7140a53d8b0c8fe01930fd65dcb38b47caae5616729c511    2
# 0xf9bb1a04afcf67b27d68b919447aa47954fc21a827d3a45215fc3830ac815021    2
# 0x12c5dd0553a378c08f81a60c4059295de312a7d90543db6ce168956f3c48c4a5    1
# 0x2acbb63026a066486b38db7b6d2f5dfeb854a65931129d795b5f3620efb83349    1
# 0x573d624188ffe8a168de9d820ada40c82ac2ae7cf2691a7ad29c7ed71415350b    1
# 0x6b7bbb0c4a7a25a3b3fb6dd9b719e36292057adc8b9f411e15de0a1e90efa215    1
# 0xb97c04cf588471ac4c13bc6217253e71f4aa0d280bb8a3961321931ec43d3929    1
# dtype: int64
