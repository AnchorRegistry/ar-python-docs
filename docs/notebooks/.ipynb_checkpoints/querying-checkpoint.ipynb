# %% [markdown]
# # Querying
#
# All five query functions demonstrated against live Sepolia data.
#
# > These examples run against Sepolia testnet (`network="sepolia"`).
# > To run against Base mainnet: replace `configure(network="sepolia")` with `configure(network="base")`.
# > All function calls, record structures, and output shapes are identical across networks.

# %%
# Cell 1 — setup
from anchorregistry import configure, get_by_arid, get_by_registrant, get_by_tree, get_by_type, get_all
from anchorregistry.enums import ArtifactType

configure(network="sepolia")

# %%
# Cell 2 — get_by_arid
# Fetch a single anchor by its AR-ID
record = get_by_arid("AR-2026-d6L3KJP")
print(f"Type:   {record['artifact_type_name']}")
print(f"Title:  {record['title']}")
print(f"Data:   {record['data']}")
# Out:
# Type:   RESEARCH
# Title:  test research
# Data:   {'doi': '', 'institution': '', 'co_authors': '', 'url': 'https://anchorregistry.ai/'}

# %%
# Cell 3 — get_by_registrant
# Fetch all anchors registered by a specific wallet address
records = get_by_registrant("0xc7a7afde1177fbf0bb265ea5a616d1b8d7ed8c44")
print(f"Total anchors by registrant: {len(records)}")
# Out:
# Total anchors by registrant: 2

# %%
# Cell 4 — get_by_tree
# Fetch all anchors belonging to a named artifact tree
records = get_by_tree("ar-operator-v1")
print(f"Total anchors in tree: {len(records)}")
# Out:
# Total anchors in tree: 2

# %%
# Cell 5 — get_by_type
# Fetch all anchors of a given artifact type
research_anchors = get_by_type(ArtifactType.RESEARCH)
print(f"RESEARCH anchors on Sepolia: {len(research_anchors)}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Cell 5 — get_by_type
#       2 # Fetch all anchors of a given artifact type
# ----> 3 research_anchors = get_by_type(ArtifactType.RESEARCH)
#       4 print(f"RESEARCH anchors on Sepolia: {len(research_anchors)}")
#
# File ~/repos/ar-python/.claude/worktrees/zen-nightingale/anchorregistry/client.py:180, in get_by_type(artifact_type, rpc_url)
#     163 """Fetch all anchors of a specific artifact type.
#     164
#     165 Post-filter on decoded ``artifactType`` from event data.
#    (...)    177     List of two-level anchor records matching the type.
#     178 """
#     179 type_index = int(artifact_type)
# --> 180 records = get_all(rpc_url=rpc_url)
#     181 return [r for r in records if r["artifact_type_index"] == type_index]
#
# File ~/repos/ar-python/.claude/worktrees/zen-nightingale/anchorregistry/client.py:210, in get_all(from_block, to_block, rpc_url)
#     208 start = from_block if from_block is not None else (deploy_block or 0)
#     209 end = to_block if to_block is not None else "latest"
# --> 210 logs = _get_logs(w3, contract.address, start, end)
#     211 return [_build_record(w3, contract, log) for log in logs]
#
# File ~/repos/ar-python/.claude/worktrees/zen-nightingale/anchorregistry/rpc.py:87, in _get_logs(w3, contract_address, from_block, to_block, topic_1, topic_2, topic_3)
#      84 while topics and topics[-1] is None:
#      85     topics.pop()
# ---> 87 logs = w3.eth.get_logs(
#      88     {
#      89         "address": Web3.to_checksum_address(contract_address),
#      90         "fromBlock": from_block,
#      91         "toBlock": to_block,
#      92         "topics": topics,
#      93     }
#      94 )
#      95 return list(logs)
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/eth/eth.py:467, in Eth.get_logs(self, filter_params)
#     463 def get_logs(
#     464     self,
#     465     filter_params: FilterParams,
#     466 ) -> List[LogReceipt]:
# --> 467     return self._get_logs(filter_params)
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/module.py:112, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     105     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     107 (
#     108     result_formatters,
#     109     error_formatters,
#     110     null_result_formatters,
#     111 ) = response_formatters
# --> 112 result = w3.manager.request_blocking(
#     113     method_str, params, error_formatters, null_result_formatters
#     114 )
#     115 return apply_result_formatters(result_formatters, result)
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/manager.py:232, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     222 def request_blocking(
#     223     self,
#     224     method: Union[RPCEndpoint, Callable[..., RPCEndpoint]],
#    (...)    227     null_result_formatters: Optional[Callable[..., Any]] = None,
#     228 ) -> Any:
#     229     """
#     230     Make a synchronous request using the provider
#     231     """
# --> 232     response = self._make_request(method, params)
#     233     return self.formatted_response(
#     234         response, params, error_formatters, null_result_formatters
#     235     )
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/manager.py:163, in RequestManager._make_request(self, method, params)
#     159 request_func = provider.request_func(
#     160     cast("Web3", self.w3), cast("MiddlewareOnion", self.middleware_onion)
#     161 )
#     162 self.logger.debug("Making request. Method: %s", method)
# --> 163 return request_func(method, params)
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
#     [... skipping similar frames: Web3Middleware.wrap_make_request.<locals>.middleware at line 56 (2 times)]
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/_utils/caching/caching_utils.py:261, in handle_request_caching.<locals>.wrapper(provider, method, params)
#     259         return response
#     260 else:
# --> 261     return func(provider, method, params)
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/providers/rpc/rpc.py:166, in HTTPProvider.make_request(self, method, params)
#     162 self.logger.debug(
#     163     "Making request HTTP. URI: %s, Method: %s", self.endpoint_uri, method
#     164 )
#     165 request_data = self.encode_rpc_request(method, params)
# --> 166 raw_response = self._make_request(method, request_data)
#     167 response = self.decode_rpc_response(raw_response)
#     168 self.logger.debug(
#     169     "Getting response HTTP. URI: %s, Method: %s, Response: %s",
#     170     self.endpoint_uri,
#     171     method,
#     172     response,
#     173 )
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/providers/rpc/rpc.py:153, in HTTPProvider._make_request(self, method, request_data)
#     151                 continue
#     152             else:
# --> 153                 raise e
#     154     return None
#     155 else:
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/providers/rpc/rpc.py:143, in HTTPProvider._make_request(self, method, request_data)
#     141 for i in range(self.exception_retry_configuration.retries):
#     142     try:
# --> 143         return self._request_session_manager.make_post_request(
#     144             self.endpoint_uri, request_data, **self.get_request_kwargs()
#     145         )
#     146     except tuple(self.exception_retry_configuration.errors) as e:
#     147         if i < self.exception_retry_configuration.retries - 1:
#
# File /opt/homebrew/lib/python3.14/site-packages/web3/_utils/http_session_manager.py:155, in HTTPSessionManager.make_post_request(self, endpoint_uri, data, **kwargs)
#     150 timeout = kwargs["timeout"]
#     152 with self.get_response_from_post_request(
#     153     endpoint_uri, data=data, **kwargs
#     154 ) as response:
# --> 155     response.raise_for_status()
#     156     if kwargs.get("stream"):
#     157         return self._handle_streaming_response(response, start, timeout)
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://sepolia.infura.io/v3/9624e3e5c40f4ac3958b79fa5aa2562d

# %%
# Cell 6 — get_all
# Reconstruct the full registry — all anchors from deploy block to latest
all_records = get_all()
print(f"Total anchors on Sepolia: {len(all_records)}")
# Out:
# Total anchors on Sepolia: 2
